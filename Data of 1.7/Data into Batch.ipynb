# %%
import pandas as pd
import google.generativeai as genai
import time

# 1. Load Data
df = pd.read_excel("Laptop_Train_v2.csv")
sentences = df['sentences'].tolist()

# 2. Batching Function
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

results = []

# 3. Iterate through batches
for batch in chunker(sentences, 200):
    prompt = f"Perform ABSA on these sentences. Return JSON list with keys 'sentence', 'aspect', 'sentiment': {batch}"
    
    # Call Gemini API
    response = model.generate_content(prompt)
    
    # Process response and append to results list...
    # (Add a time.sleep(2) here to avoid hitting rate limits)

# 4. Save
pd.DataFrame(results).to_excel("absa_results.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import google.generativeai as genai
#       3 import time
#       5 # 1. Load Data
#
# ModuleNotFoundError: No module named 'google.generativeai'

# %%
import pandas as pd

# PASTE YOUR FULL DATA LIST HERE
data = [
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "service center",
          "polarity": "negative"
        },
        {
          "term": "sales team",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "quality",
          "polarity": "positive"
        },
        {
          "term": "GUI",
          "polarity": "positive"
        },
        {
          "term": "applications",
          "polarity": "positive"
        },
        {
          "term": "use",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "start up",
          "polarity": "positive"
        },
        {
          "term": "overheat",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "features",
          "polarity": "positive"
        },
        {
          "term": "iChat",
          "polarity": "positive"
        },
        {
          "term": "Photobooth",
          "polarity": "positive"
        },
        {
          "term": "garage band",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "features",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "GUI",
          "polarity": "negative"
        },
        {
          "term": "screen",
          "polarity": "negative"
        },
        {
          "term": "power light",
          "polarity": "negative"
        },
        {
          "term": "hard drive light",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "screen",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "enclosure",
          "polarity": "positive"
        },
        {
          "term": "razor edge",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "multi-touch gestures",
          "polarity": "positive"
        },
        {
          "term": "tracking area",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "suite of software",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "speed",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Windows 7",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "usb devices",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": []
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "system",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Microsoft office",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "syncing",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Monitor",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "boot up",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "help",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "operating system",
          "polarity": "positive"
        },
        {
          "term": "preloaded software",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "price",
          "polarity": "positive"
        },
        {
          "term": "features",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "BIOS setup",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "WARRANTY SERVICE",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "brand",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "warranty",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "features",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "fan",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Customer Service",
          "polarity": "negative"
        },
        {
          "term": "technician",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "hard disc",
          "polarity": "negative"
        },
        {
          "term": "windows",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Drivers",
          "polarity": "positive"
        },
        {
          "term": "BIOS update",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Technical Support",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "browser",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keyboard",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "defrags",
          "polarity": "neutral"
        },
        {
          "term": "virus scan",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": []
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": []
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "help",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "repaired",
          "polarity": "negative"
        },
        {
          "term": "Warranty",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Quality",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "webcam",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "email",
          "polarity": "neutral"
        },
        {
          "term": "internet",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "motherboard",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "system",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "charger",
          "polarity": "negative"
        },
        {
          "term": "hardware",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "force quit",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "works",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Windows 7",
          "polarity": "positive"
        },
        {
          "term": "VMWare program",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "navigate",
          "polarity": "positive"
        },
        {
          "term": "operating system",
          "polarity": "positive"
        },
        {
          "term": "find files",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "warrenty",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "extended warranty",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "memory",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "heated up",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "operating systems",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "charger",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "download songs",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "glass touchpad",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "hard drive",
          "polarity": "negative"
        },
        {
          "term": "mother board",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "external speaker",
          "polarity": "positive"
        },
        {
          "term": "sound",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "neutral"
        },
        {
          "term": "upgrade",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "hardware",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "shipping",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "use",
          "polarity": "positive"
        },
        {
          "term": "Mac software",
          "polarity": "positive"
        },
        {
          "term": "Microsoft software",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "editing",
          "polarity": "negative"
        },
        {
          "term": "forward delete key",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "ease of use",
          "polarity": "positive"
        },
        {
          "term": "service",
          "polarity": "positive"
        },
        {
          "term": "phone assistance",
          "polarity": "positive"
        },
        {
          "term": "genius bar",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "recovery discs",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Max Assurance",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "migration",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery timer",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Temperatures",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "service",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "virus protection",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "bluetooth",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "hinge",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "games",
          "polarity": "neutral"
        },
        {
          "term": "email",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "responds",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "motherboard",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "hardware",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "motherboard",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "weight",
          "polarity": "positive"
        },
        {
          "term": "use",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "representive",
          "polarity": "negative"
        },
        {
          "term": "system",
          "polarity": "negative"
        },
        {
          "term": "XP",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "WIndows 7",
          "polarity": "positive"
        },
        {
          "term": "Vista",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Keyboard",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "customer disservice",
          "polarity": "negative"
        },
        {
          "term": "products",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "cooling system",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "render AVCHD movies",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "sales associate",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Windows applications",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "virus program",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "weighed",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "bag",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "color",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keys",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "style",
          "polarity": "positive"
        },
        {
          "term": "speed",
          "polarity": "positive"
        },
        {
          "term": "cool factor",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keyboard",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "mousepad",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "sales",
          "polarity": "positive"
        },
        {
          "term": "service",
          "polarity": "positive"
        },
        {
          "term": "SUPPORT",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "desktop",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "speed",
          "polarity": "positive"
        },
        {
          "term": "construction quality",
          "polarity": "positive"
        },
        {
          "term": "longevity",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keyboard",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "touch pad",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "ease of use",
          "polarity": "positive"
        },
        {
          "term": "security",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": []
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "preloaded software",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "webcam",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "vga port",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keys",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "load",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "volume",
          "polarity": "negative"
        },
        {
          "term": "mouse",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "touchpad",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "boots up",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "virus",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "look",
          "polarity": "positive"
        },
        {
          "term": "feel",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "safari",
          "polarity": "negative"
        },
        {
          "term": "Mozzilla firfox",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Bluetooth",
          "polarity": "negative"
        },
        {
          "term": "fingerprint reader driver",
          "polarity": "negative"
        },
        {
          "term": "software",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery",
          "polarity": "positive"
        },
        {
          "term": "speed",
          "polarity": "positive"
        },
        {
          "term": "display",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "delivery",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "battery life",
          "polarity": "positive"
        },
        {
          "term": "performance",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "applications",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Resolution",
          "polarity": "negative"
        },
        {
          "term": "appearance",
          "polarity": "negative"
        },
        {
          "term": "cooling system",
          "polarity": "negative"
        },
        {
          "term": "graphics card",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "webcam",
          "polarity": "negative"
        },
        {
          "term": "mic",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Windows Vista",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "board",
          "polarity": "negative"
        },
        {
          "term": "power supply",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "ethernet",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "drag and drop feature",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "webcam",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "sales tax",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "software packages",
          "polarity": "positive"
        },
        {
          "term": "iWork",
          "polarity": "positive"
        },
        {
          "term": "GarageBand",
          "polarity": "positive"
        },
        {
          "term": "iMovie",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "screen",
          "polarity": "positive"
        },
        {
          "term": "colors",
          "polarity": "positive"
        },
        {
          "term": "resolution",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "monitor",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "iTunes",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Size",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Toshiba-specific software",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "plastic piece",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "camera",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "display",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "AMD Turin processor",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "warranty",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "start menu",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "internal bluray read/write drive",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "service tech",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": []
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "textured surface",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "screen",
          "polarity": "positive"
        },
        {
          "term": "keyboard",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "iLife",
          "polarity": "positive"
        },
        {
          "term": "Snow Leopard X",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "price tag",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Mac OS",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "sound output quality",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "techie",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "use",
          "polarity": "positive"
        },
        {
          "term": "weight",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "online help",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "service life",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "ports",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "price",
          "polarity": "positive"
        },
        {
          "term": "look",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "keyboard",
          "polarity": "positive"
        },
        {
          "term": "chiclet type keys",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "screen",
          "polarity": "negative"
        },
        {
          "term": "travel",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Runs",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "stock screen",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "gray color",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "volume buttons",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "processor",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "protector",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "power charging power cord",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "XP",
          "polarity": "positive"
        },
        {
          "term": "Vista",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "use",
          "polarity": "positive"
        },
        {
          "term": "graphics",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Mac OS",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "support",
          "polarity": "positive"
        },
        {
          "term": "products",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Geek Squad",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "graphics quality",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Appleworks",
          "polarity": "negative"
        },
        {
          "term": "browser",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "paint",
          "polarity": "negative"
        },
        {
          "term": "keyboard",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "service department",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "warrenty",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "backup hard disk",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "CD drive",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "screen size",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "loads",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "trackpad",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "games",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "human interface",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "inbuilt applications",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "body",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "rendering videos",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "antivirus software",
          "polarity": "positive"
        },
        {
          "term": "firewall",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "price",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Apple team",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Vista",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "video chat",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "portable mouse",
          "polarity": "neutral"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "Fan vents",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "software",
          "polarity": "positive"
        },
        {
          "term": "load",
          "polarity": "positive"
        },
        {
          "term": "use",
          "polarity": "positive"
        },
        {
          "term": "viruses",
          "polarity": "positive"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "installation",
          "polarity": "negative"
        }
      ]
    }
  },
  {
    "name": "extract_aspects_and_polarities",
    "description": "Extract sentiment aspects and polarities from a text",
    "parameters": {
      "aspects": [
        {
          "term": "power",
          "polarity": "positive"
        },
        {
          "term": "storage",
          "polarity": "positive"
        },
        {
          "term": "abilitiy",
          "polarity": "positive"
        }
      ]
    }
  }
]

# 1. Extract just the 'aspects' lists
# We use a list comprehension to grab the aspects list, 
# but we also want to keep the index so we know which review it came from.
flattened_data = []

for i, entry in enumerate(data):
    aspects = entry.get('parameters', {}).get('aspects', [])
    for aspect in aspects:
        flattened_data.append({
            'Record_ID': i + 1,
            'Term': aspect.get('term'),
            'Polarity': aspect.get('polarity')
        })

# 2. Convert to DataFrame
df = pd.DataFrame(flattened_data)

# 3. Save to CSV
df.to_csv('sentiment_output_pandas.csv', index=False)

print("CSV created successfully.")
print(df.head()) # Prints the first few rows to verify
# Out:
# CSV created successfully.
#    Record_ID            Term  Polarity
# 0          1    battery life  positive
# 1          2  service center  negative
# 2          2      sales team   neutral
# 3          3         quality  positive
# 4          3             GUI  positive
